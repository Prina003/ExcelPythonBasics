# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
pd.read_excel('exl.xlsx')
# Out:
#   Unnamed: 0       City Country  Math  Science
# 0     Prina     Patiala   India    79       81
# 1      Namta  Panchkula   India   100       98
# 2      Arpit  Panchkula   India    95       96

# %%
pd.read_excel('exl.xlsx',index_col=0)
# Out:
#              City Country  Math  Science
# Prina     Patiala   India    79       81
# Namta   Panchkula   India   100       98
# Arpit   Panchkula   India    95       96

# %%
pd.read_excel('exl.xlsx',index_col=0,header=0)
# Out:
#              City Country  Math  Science
# Prina     Patiala   India    79       81
# Namta   Panchkula   India   100       98
# Arpit   Panchkula   India    95       96

# %%
pd.read_excel('exl.xlsx',index_col=0,usecols='A:C')
# Out:
#              City Country
# Prina     Patiala   India
# Namta   Panchkula   India
# Arpit   Panchkula   India

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
rows= pd.read_excel('Book1.xlsx',index_col=0)
rows.tail(4)
# Out:
#                  City  Maths  Science
# Charlie  Philadelphia     36       44
# Anthony        London     61       67
# Hema         Dehradun     56       52
# Lily           Munich     89       75

# %%
import cv2

# %%
import numpy as np

# %%
from google.colab.patches import cv2_imshow

# %%
i = cv2.imread('quilling.jpg')

# %%
cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=RGB size=474x632>

# %%
gray = cv2.cvtColor(i,cv2.COLOR_BGR2HSV)

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=RGB size=474x632>

# %%
ib = i[:,:,0]  # the first page B matrix
ig = i[:,:,1]  # second page G matrix
ir = i[:,:,2]  # third page R matrix
all3 = np.hstack((ib,ig,ir))
cv2_imshow(all3)
# Out:
# <PIL.Image.Image image mode=L size=1422x632>

# %%
temp = i
temp[:,:,1]=0
cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=RGB size=474x632>

# %%
resizeimg = cv2.resize(gray,(256,256))
cv2_imshow(resizeimg)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
i = cv2.imread('quilling.jpg')

# %%
cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=RGB size=474x632>

# %%
resizeimg = cv2.resize(i,(256,256))
cv2_imshow(resizeimg)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
print(i.shape)
# Out:
# (632, 474, 3)

# %%
gflip=cv2.flip(resizeimg,-1)
cv2_imshow(gflip)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
import cv2

# %%
import numpy as np

# %%
from google.colab.patches import cv2_imshow

# %%
i = cv2.imread('april4py.jpg')

# %%
cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=RGB size=320x490>

# %%
noisy_image = cv2.imread('april4py.jpg')
denoised_image = cv2.medianBlur(noisy_image, 15)
cv2_imshow(noisy_image)
cv2_imshow(denoised_image)
# Out:
# <PIL.Image.Image image mode=RGB size=320x490>
# <PIL.Image.Image image mode=RGB size=320x490>
